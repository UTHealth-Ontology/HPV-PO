# %%
import csv, urllib.parse, types
from owlready2 import get_ontology, World
from owlready2 import *
from owlready2.prop import ObjectPropertyClass, define_datatype_in_ontology, OneOf, DataPropertyClass, DatatypeClass, Datatype
import re
from typing import Dict, Any, List

# %%
PURL_IMPORTS = [
    'https://raw.githubusercontent.com/UTHealth-Ontology/HPV-PO/refs/heads/main/imports/iao-extract.owl',
    'http://purl.obolibrary.org/obo/bfo/2019-08-26/bfo.owl',
    'https://raw.githubusercontent.com/UTHealth-Ontology/HPV-PO/refs/heads/NCITmap/imports/OPMI-extract.owl',
    'https://raw.githubusercontent.com/UTHealth-Ontology/HPV-PO/refs/heads/NCITmap/imports/omrse-extract.owl',
    'https://raw.githubusercontent.com/UTHealth-Ontology/HPV-PO/refs/heads/NCITmap/imports/NCIT_OBO-extract.owl',
    'https://raw.githubusercontent.com/UTHealth-Ontology/HPV-PO/refs/heads/NCITmap/imports/gsso-extract.owl',
    'https://raw.githubusercontent.com/UTHealth-Ontology/HPV-PO/refs/heads/NCITmap/imports/OBI-extract.owl',
    'https://raw.githubusercontent.com/UTHealth-Ontology/HPVCO/refs/heads/main/hpvco.rdf'

]

# %%
# CSV_FILE     = "new_hpvpo_terms.csv"
CSV_FILE     = "new_hpvpo_terms_names.csv"
CSV_FILE_1     = "new_object_properties.csv"
TARGET_IRI   = "http://purl.org/uth/ontology/hpv-po.owl#"
OUTPUT_FILE  = "hpv-po.owl"
ID_PREFIX    = "HPVPO_"
DIGITS       = 7

# %%
DELIMS = [";", "|"]                          # accepted separators

def split_labels(cell: str):
    """Return a list of trimmed labels from a CSV cell."""
    for d in DELIMS:
        if d in cell:
            return [part.strip() for part in cell.split(d) if part.strip()]
    return [cell.strip()]

# %%
world = World()
hpvpo = world.get_ontology(TARGET_IRI)
for purl in PURL_IMPORTS:
    hpvpo.imported_ontologies.append(world.get_ontology(purl).load())

# %%
id_regex = re.compile(rf"{ID_PREFIX}(\d{{{DIGITS}}})$")

def next_hpvp_id():
    nums = []
    entities = (
        list(hpvpo.classes()) +
        list(hpvpo.object_properties()) +
        list(hpvpo.data_properties()) +
        list(hpvpo.annotation_properties()) +
        list(hpvpo.individuals()) 
    )
    for ent in entities:
        m = id_regex.search(ent.name)
        if m:
            nums.append(int(m.group(1)))
    nxt = max(nums) + 1 if nums else 1
    return f"{ID_PREFIX}{nxt:0{DIGITS}}"

def find_class_by_label(label_text):
    return world.search_one(label = label_text)

# def local_name(iri):
#     frag = urllib.parse.urlparse(iri).fragment
#     return frag if frag else iri.rsplit("/", 1)[-1]

# %% [markdown]
# ## Class Automation

# %%
# New: label based class creation
with hpvpo:
    with open(CSV_FILE, newline="", encoding="utf-8-sig") as fh:
        reader = csv.DictReader(fh)
        for row in reader:
            parent_label = row["parent_label"].strip()
            new_label    = row["entity_label"].strip()

            parent_cls = find_class_by_label(parent_label)
            if parent_cls is None:
                print(f"⚠ Parent with label '{parent_label}' not found — skipping '{new_label}'")
                continue

            new_name = next_hpvp_id()
            new_cls  = types.new_class(new_name, (parent_cls,))
            new_cls.label = [new_label]

            # print(f"✔  {new_label}  ({new_cls.name})  subclassOf {parent_cls.label[0]}")

# %%
# # OLD: IRI based class creation
# with hpvpo:
#     with open(CSV_FILE, newline="", encoding="utf-8-sig") as fh:
#         reader = csv.DictReader(fh)
#         for row in reader:
#             iri         = row["CIRI"].strip()
#             parent_iri  = row["PIRI"].strip()
#             label       = row["concept_name"].strip()

#             parent_cls = world[parent_iri]
#             # print("parent_cls:", parent_cls)
#             if parent_cls is None:
#                 print(f"⚠  Parent not found, skipping → {iri}: PARENT {parent_iri}")
#                 continue


#             local_name = urllib.parse.urlparse(iri).fragment or iri.rsplit("/", 1)[-1]


#             if world[iri]:
#                 print(f"•  {iri} already present, skipping")
#                 continue

#             new_cls = types.new_class(local_name, (parent_cls,))
#             if label:
#                 new_cls.label = [label]   

                 
#             print(f"✔  Added {label}  (subclass of {parent_cls.label})")

# %%
# # OLD: IRI based property creation
# with hpvpo:
#     with CSV_FILE.open(newline="", encoding="utf-8") as fh:
#         reader = csv.DictReader(fh)
#         for row in reader:
#             iri        = row["iri"].strip()
#             parent_iri = row["parent_iri"].strip()
#             domain_iri = row["domain_iri"].strip()
#             range_iri  = row["range_iri"].strip()
#             label      = row.get("label", "").strip()

#             # look up parent property
#             parent_prop = world[parent_iri]
#             if parent_prop is None or not isinstance(parent_prop, ObjectPropertyClass):
#                 print(f"⚠ parent property not found or not object property → {parent_iri}")
#                 continue

#             # look up domain / range classes
#             domain_cls = world[domain_iri]
#             range_cls  = world[range_iri]
#             if domain_cls is None or range_cls is None:
#                 print(f"⚠ domain/range class not found for {iri}")
#                 continue

#             # skip if already exists
#             if world[iri]:
#                 print(f"• {iri} already present, skipping")
#                 continue

#             # create the new sub-property
#             prop_name = local_name(iri)
#             new_prop = types.new_class(prop_name,(parent_prop,),
#                 kwds={"iri": iri}
#             )

#             # attach domain & range axioms (lists accepted by Owlready2)
#             new_prop.domain = [domain_cls]
#             new_prop.range  = [range_cls]

#             if label:
#                 new_prop.label = [label]

#             print(f"✔ added property {label or prop_name}  subPropertyOf {parent_prop.name}")

# %% [markdown]
# ## Property Automation

# %%
# New: label based property creation
with hpvpo:
    with open(CSV_FILE_1, newline="", encoding="utf-8-sig") as fh:
        reader = csv.DictReader(fh)
        for row in reader:
            property_label = row["property_label"].strip()
            superproperty_label = row["superproperty_label"].strip()
            domain_labels = split_labels(row["domain"])
            range_labels  = split_labels(row["range"])

            # print(f"Processing property: {property_label}  subPropertyOf {superproperty_label}  domain {domain}  range {range}")

            # look up parent property
            parent_prop = find_class_by_label(superproperty_label)
            if parent_prop is None or not isinstance(parent_prop, ObjectPropertyClass):
                print(f"⚠ parent property not found or not object property → {superproperty_label}")
                continue

            # look up domain / range classes
            domain_classes, range_classes = [], []
            missing = False
            for lbl in domain_labels:
                cls = find_class_by_label(lbl)
                if cls: domain_classes.append(cls)
            for lbl in range_labels:
                cls = find_class_by_label(lbl)
                if cls: range_classes.append(cls)

            # create the new sub-property
            prop_name = next_hpvp_id()
            # print(f"Creating property: {prop_name}  subPropertyOf {parent_prop.name}")
            new_prop = types.new_class(prop_name,(parent_prop,))

            # attach domain & range axioms (lists accepted by Owlready2)
            if domain_classes:
                new_prop.domain = domain_classes
            if range_classes:
                new_prop.range  = range_classes
            new_prop.label = [property_label]

            # print(f"✔ added property {property_label}  subPropertyOf {parent_prop.name}")

# %% [markdown]
# ### Data Properties

# %%
# Enumerated Datatypes: 
with hpvpo:
    class BeliefLevel(Datatype):
        equivalent_to = [ OneOf(["low", "moderate", "high"]) ]
        label = "Belief Level"
   
    class has_belief_level(DataProperty):
        domain = [find_class_by_label("belief")]
        range = [BeliefLevel]
        label = "has_belief_level"

    class LiteracyLevel(Datatype):
        equivalent_to = [ OneOf(["low", "moderate", "high"]) ]
        label = "Literacy Level"

    class has_literacy_level(DataProperty):
        domain = [find_class_by_label("literacy")]
        range = [LiteracyLevel]
        label = "has_literacy_level"

    class SeverityLevel(Datatype):
        equivalent_to = [ OneOf(["low", "moderate", "high"]) ]
        label = "Severity Level"
    
    class has_severity_level(DataProperty):
        domain = [find_class_by_label("disposition")]
        range = [SeverityLevel]
        label = "has_severity_level"

    class has_access_level(DataProperty):
        domain = [find_class_by_label("Healthcare Access and Quality")]
        range = [bool]
        label = "has_access_level"

    class has_vaccination_history(DataProperty):
        domain = [find_class_by_label("positive vaccination history")]
        range = [bool]
        label = "has_vaccination_history"

    class has_value_in_years(DataProperty):
        domain = [find_class_by_label("Age")]
        range = [int]
        label = "has_value_in_years"

    class DiscussionFrequency(Datatype):
        equivalent_to = [ OneOf(["regular", "rare"]) ]
        label = "Discussion Frequency"

    class has_discussion_frequency(DataProperty):
        domain = [find_class_by_label("healthcare provider discussion behavior")]
        range = [DiscussionFrequency]
        label = "has_discussion_frequency"

# %%
# data_props: Dict[str, Dict[str, Any]] = {
#     "has_belief_level": {
#         "label" : "has_belief_level",
#         "domain": "belief",
#         "range" : "BeliefLevel",
#         # "enum_values" : ["low", "moderate", "high"]
#     },
#     "has_knowledge_level": {
#         "label" : "has_knowledge_level",
#         "domain": "knowledge",
#         "range" : "KnowledgeLevel",
#         # "enum_values" : ["low", "moderate", "high"]
#     },
#     "has_access_level": {
#         "label" : "has_access_level",
#         "domain": "Healthcare Access and Quality",
#         "range" : "xsd:bool"
#     },
#     "has_vaccination_history": {
#         "label" : "has_vaccination_history",
#         "domain": "positive vaccination history",
#         "range" : "xsd:bool"
#     },
#     "has_severity": {
#         "label" : "has_severity",
#         "domain": "disposition",
#         "range" : "SeverityLevel",
#         # "enum_values" : ["low", "moderate", "high"]
#     },
# }

# %%
# # Unfixable
# with hpvpo:
#     for name, spec in data_props.items():
#         label   = spec["label"]
#         domain  = find_class_by_label(spec["domain"])
#         range  = spec["range"]
        
#         if domain is None:
#             raise ValueError(f"Domain not found for {name}")
        
#         # create datatype for range
#         if range.startswith("xsd:"):
#             if range == "xsd:bool":
#                dtype = bool

#         else:
#             # assume it's an enum type
#             iri = TARGET_IRI + range
#             print(iri)
#             dtype = IRIS[iri]
#             print(dtype.label)
#         #     lit_list = list(spec.get("enum_values", []))
#         #     #create a class for the datatype
#         #     dtype_name = range
#         #     dtype = types.new_class(dtype_name,(Datatype,))
#         #     dtype.equivalent_to = [OneOf(lit_list)]
#         #     dtype.label = [range]
#         #     # print(dtype.label, dtype.name, type(dtype))

#         # create DatatypeProperty (using new_class)
#         prop_name = next_hpvp_id()
#         prop = types.new_class(prop_name,(DataProperty,))
#         print(f"Creating data property: {prop} , {prop.label}  domain={domain} {domain.label}  range={dtype}")
#         prop.domain = [domain]
#         prop.range  = [dtype]
#         prop.label  = [label]
#         print(f"SUCCESS: created {prop.name}  domain={domain.name}  range={dtype.name}")

#         # print(f"✔ created {prop.name}  domain={domain.name}  range={dtype.name}")
#         # print(f"✔ created {prop.name}  domain={domain.label}")

# %% [markdown]
# ### Instance Automation

# %%
# functions need to be translated to java since dialog engine uses owlapi and java

# %%
I_CSV = "test_instance_template.csv"

# %%
with hpvpo:
    with open(I_CSV, newline="", encoding="utf-8-sig") as fh:
        reader = csv.DictReader(fh)
        for row in reader:
            subj_label   = row["subject"].strip()
            subj_parent_l = row["subject_parent"].strip()
            pred_label   = row["predicate"].strip()
            obj_label    = row["object"].strip()
            obj_parent_l = row["object_parent"].strip()
            data_prop = row["data_property"].strip()
            data_value = row["data_value"].strip()

            # ---------- subject parent class ----------------------
            s_parent_cls = find_class_by_label(subj_parent_l)
            if s_parent_cls is None or not isinstance(s_parent_cls, type):
                raise ValueError(f"Parent class '{subj_parent_l}' not found!")
            
            # ---------- subject individual ---------------------------
            subj_ind = find_class_by_label(subj_label)
            if subj_ind is None:
                sub_name = next_hpvp_id()
                subj_ind = s_parent_cls(sub_name)     
                subj_ind.label = [subj_label]

            # ---------- object parent class --------------------------
            o_parent_cls = find_class_by_label(obj_parent_l)
            if o_parent_cls is None or not isinstance(o_parent_cls, type):
                raise ValueError(f"Parent class '{obj_parent_l}' not found!")

            # # ---------- object individual ----------------------------
            obj_ind = find_class_by_label(obj_label)
            if obj_ind is None:
                obj_name = next_hpvp_id()
                obj_ind = o_parent_cls(obj_name)   
                obj_ind.label = [obj_label]

            # ---------- object property ------------------------------
            prop = find_class_by_label(pred_label)
            if prop is None:
                raise ValueError(f"Object property '{pred_label}' not found!")

            # ---------- assert the triple ----------------------------
            prop[subj_ind].append(obj_ind)
            if data_prop and data_value:
                data_prop_cls = find_class_by_label(data_prop)
                if data_prop_cls is None or not isinstance(data_prop_cls, DataPropertyClass):
                    raise ValueError(f"Data property '{data_prop}' not found!")
                # set the data property value
                if data_value.lower() == "true": # boolean
                    data_prop_cls[obj_ind] = [True]
                elif data_value.lower() == "false":
                    data_prop_cls[obj_ind] = [False]
                elif data_value.isdigit():  # integer
                    data_prop_cls[obj_ind] = [int(data_value)]
                else:
                    data_prop_cls[obj_ind].append(data_value)
            # print(f"✔ {subj_ind.name}  -{prop.name}-->  {obj_ind.name}")

# %%
hpvpo.save(file=OUTPUT_FILE, format="rdfxml")
print(f"\nOntology saved to {OUTPUT_FILE}")
# Out:
# Ontology saved to hpv-po.owl
